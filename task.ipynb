# %%
import seaborn as sns

# %%
df= sns.load_dataset("car_crashes")
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
new_list = [("NUM_"+col).upper() for col in df.columns]

# %%
new_list
# Out:
# ['NUM_TOTAL',
#  'NUM_SPEEDING',
#  'NUM_ALCOHOL',
#  'NUM_NOT_DISTRACTED',
#  'NUM_NO_PREVIOUS',
#  'NUM_INS_PREMIUM',
#  'NUM_INS_LOSSES',
#  'NUM_ABBREV']

# %%
df.columns = new_list

# %%
df.columns
# Out:
# Index(['NUM_TOTAL', 'NUM_SPEEDING', 'NUM_ALCOHOL', 'NUM_NOT_DISTRACTED',
#        'NUM_NO_PREVIOUS', 'NUM_INS_PREMIUM', 'NUM_INS_LOSSES', 'NUM_ABBREV'],
#       dtype='object')

# %%
df.head()
# Out:
#    NUM_TOTAL  NUM_SPEEDING  NUM_ALCOHOL  NUM_NOT_DISTRACTED  NUM_NO_PREVIOUS  \
# 0       18.8         7.332        5.640              18.048           15.040
# 1       18.1         7.421        4.525              16.290           17.014
# 2       18.6         6.510        5.208              15.624           17.856
# 3       22.4         4.032        5.824              21.056           21.280
# 4       12.0         4.200        3.360              10.920           10.680
#
#    NUM_INS_PREMIUM  NUM_INS_LOSSES NUM_ABBREV
# 0           784.55          145.08         AL
# 1          1053.48          133.93         AK
# 2           899.47          110.35         AZ
# 3           827.34          142.39         AR
# 4           878.41          165.63         CA

# %%
df= sns.load_dataset("car_crashes")

# %%
import pygame
import time
import random

# Initialize pygame
pygame.init()

# Define colors
white = (255, 255, 255)
yellow = (255, 255, 102)
black = (0, 0, 0)
red = (213, 50, 80)
green = (0, 255, 0)
blue = (50, 153, 213)

# Define the display dimensions
dis_width = 600
dis_height = 400

# Initialize the display
dis = pygame.display.set_mode((dis_width, dis_height))
pygame.display.set_caption('Snake Game by ChatGPT')

clock = pygame.time.Clock()
snake_block = 10
snake_speed = 15

# Define the font style
font_style = pygame.font.SysFont("bahnschrift", 25)
score_font = pygame.font.SysFont("comicsansms", 35)

def our_snake(snake_block, snake_list):
    for x in snake_list:
        pygame.draw.rect(dis, black, [x[0], x[1], snake_block, snake_block])

def message(msg, color):
    mesg = font_style.render(msg, True, color)
    dis.blit(mesg, [dis_width / 6, dis_height / 3])

def gameLoop():
    game_over = False
    game_close = False

    x1 = dis_width / 2
    y1 = dis_height / 2

    x1_change = 0
    y1_change = 0

    snake_List = []
    Length_of_snake = 1

    foodx = round(random.randrange(0, dis_width - snake_block) / 10.0) * 10.0
    foody = round(random.randrange(0, dis_height - snake_block) / 10.0) * 10.0

    while not game_over:

        while game_close == True:
            dis.fill(blue)
            message("You Lost! Press Q-Quit or C-Play Again", red)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False
                    if event.key == pygame.K_c:
                        gameLoop()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                game_over = True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x1_change = -snake_block
                    y1_change = 0
                elif event.key == pygame.K_RIGHT:
                    x1_change = snake_block
                    y1_change = 0
                elif event.key == pygame.K_UP:
                    y1_change = -snake_block
                    x1_change = 0
                elif event.key == pygame.K_DOWN:
                    y1_change = snake_block
                    x1_change = 0

        if x1 >= dis_width or x1 < 0 or y1 >= dis_height or y1 < 0:
            game_close = True
        x1 += x1_change
        y1 += y1_change
        dis.fill(blue)
        pygame.draw.rect(dis, green, [foodx, foody, snake_block, snake_block])
        snake_Head = []
        snake_Head.append(x1)
        snake_Head.append(y1)
        snake_List.append(snake_Head)
        if len(snake_List) > Length_of_snake:
            del snake_List[0]

        for x in snake_List[:-1]:
            if x == snake_Head:
                game_close = True

        our_snake(snake_block, snake_List)

        pygame.display.update()

        if x1 == foodx and y1 == foody:
            foodx = round(random.randrange(0, dis_width - snake_block) / 10.0) * 10.0
            foody = round(random.randrange(0, dis_height - snake_block) / 10.0) * 10.0
            Length_of_snake += 1

        clock.tick(snake_speed)

    pygame.quit()
    quit()

gameLoop()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 119
#     116     pygame.quit()
#     117     quit()
# --> 119 gameLoop()
#
# Cell In[14], line 69, in gameLoop()
#      67                 game_close = False
#      68             if event.key == pygame.K_c:
# ---> 69                 gameLoop()
#      71 for event in pygame.event.get():
#      72     if event.type == pygame.QUIT:
#
# Cell In[14], line 59, in gameLoop()
#      56 while not game_over:
#      58     while game_close == True:
# ---> 59         dis.fill(blue)
#      60         message("You Lost! Press Q-Quit or C-Play Again", red)
#      61         pygame.display.update()
#
# error: display Surface quit

# %%
new_list = [(col+ "_FLAG").upper() if "no" not in col else col.upper() for col in df.columns ]

# %%
new_list
# Out:
# ['TOTAL_FLAG',
#  'SPEEDING_FLAG',
#  'ALCOHOL_FLAG',
#  'NOT_DISTRACTED',
#  'NO_PREVIOUS',
#  'INS_PREMIUM_FLAG',
#  'INS_LOSSES_FLAG',
#  'ABBREV_FLAG']

# %%
og_list = ["abbrev", "no_previous"]

# %%
new_list = [col  for col in df.columns if col not in og_list ]

# %%
new_list
# Out:
# ['total', 'speeding', 'alcohol', 'not_distracted', 'ins_premium', 'ins_losses']

# %%
new_df = df[new_list]
new_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  ins_premium  ins_losses
# 0   18.8     7.332    5.640          18.048       784.55      145.08
# 1   18.1     7.421    4.525          16.290      1053.48      133.93
# 2   18.6     6.510    5.208          15.624       899.47      110.35
# 3   22.4     4.032    5.824          21.056       827.34      142.39
# 4   12.0     4.200    3.360          10.920       878.41      165.63

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df = sns.load_dataset("titanic")

# %%
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df["pclass"].nunique()
# Out:
# 3

# %%
df[["pclass","parch"]].nunique()
# Out:
# pclass    3
# parch     7
# dtype: int64

# %%
df["embarked"].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df["embarked"] = df["embarked"].astype("category")

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked       category
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df[df["embarked"] == "C"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df[df["embarked"] != "S"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df[(df["age"] < 30) & (df["sex"] == "male")]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# 16          0       3  male   2.0      4      1  29.1250        Q   Third
# 23          1       1  male  28.0      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 877         0       3  male  19.0      0      0   7.8958        S   Third
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df["fare"] > 500) | (df["age"] > 70)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 116         0       3    male  70.5      0      0    7.7500        Q  Third
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 493         0       1    male  71.0      0      0   49.5042        C  First
# 630         1       1    male  80.0      0      0   30.0000        S  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 851         0       3    male  74.0      0      0    7.7750        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df = df.drop(columns = ["who"])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
new_df_deck = df["deck"].fillna(value = df["deck"].mode()[0])

# %%
df["deck"] = new_df_deck

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False    C  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True    C  Southampton    no   True

# %%
new_df_age = df["age"].fillna(value = df["age"].median())

# %%
new_df_age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df["age"] = new_df_age

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False    C  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True    C  Southampton    no   True

# %%
df.groupby(["pclass","sex"]).agg({
    "survived":["sum","count","mean"]
})
# Out:
#               survived
#                    sum count      mean
# pclass sex
# 1      female       91    94  0.968085
#        male         45   122  0.368852
# 2      female       70    76  0.921053
#        male         17   108  0.157407
# 3      female       72   144  0.500000
#        male         47   347  0.135447

# %%
df["age"].apply(lambda x:1 if x<30  else 0)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: age, dtype: int64

# %%
df["age_flag"] = df["age"].apply(lambda x:1 if x<30  else 0)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone  age_flag
# 0        True    C  Southampton    no  False         1
# 1       False    C    Cherbourg   yes  False         0
# 2       False    C  Southampton   yes   True         1
# 3       False    C  Southampton   yes  False         0
# 4        True    C  Southampton    no   True         0

# %%
df2 = sns.load_dataset("tips")
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2.groupby(["time"]).agg({
    "total_bill": ["sum","min","max","mean"]
})
# Out:
# /var/folders/39/15zp5wjs7wq3fwkgthfgz4bc0000gn/T/ipykernel_9201/1905498963.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2.groupby(["time"]).agg({
#        total_bill
#               sum   min    max       mean
# time
# Lunch     1167.47  7.51  43.11  17.168676
# Dinner    3660.30  3.07  50.81  20.797159

# %%
df2.groupby(["time","day"]).agg({
    "total_bill": ["sum","min","max","mean"]
})
# Out:
# /var/folders/39/15zp5wjs7wq3fwkgthfgz4bc0000gn/T/ipykernel_9201/688928645.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2.groupby(["time","day"]).agg({
#             total_bill
#                    sum    min    max       mean
# time   day
# Lunch  Thur    1077.55   7.51  43.11  17.664754
#        Fri       89.92   8.58  16.27  12.845714
#        Sat        0.00    NaN    NaN        NaN
#        Sun        0.00    NaN    NaN        NaN
# Dinner Thur      18.78  18.78  18.78  18.780000
#        Fri      235.96   5.75  40.17  19.663333
#        Sat     1778.40   3.07  50.81  20.441379
#        Sun     1627.16   7.25  48.17  21.410000

# %%
df2.groupby(["time","sex"]).agg({
    "total_bill": ["sum","min","max","mean"],
    "tip" : ["sum","min","max","mean"]
}).loc[('Lunch', 'Female')]
# Out:
# /var/folders/39/15zp5wjs7wq3fwkgthfgz4bc0000gn/T/ipykernel_9201/2633026966.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2.groupby(["time","sex"]).agg({
# total_bill  sum     571.870000
#             min       8.350000
#             max      43.110000
#             mean     16.339143
# tip         sum      90.400000
#             min       1.250000
#             max       5.170000
#             mean      2.582857
# Name: (Lunch, Female), dtype: float64

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#df2.loc[(df2['size'] < 3) & (df2['total_bill'] > 10)].mean()

# %%
df2.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df2.loc[(df2['size'] < 3) & (df2['total_bill'] > 10)].select_dtypes(include='number').mean()
# Out:
# total_bill    17.184965
# tip            2.638811
# size           1.993007
# dtype: float64

# %%
df2["total_bill_tip_sum"] = df2["total_bill"] + df2["tip"]

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_bill_tip_sum
# 0       16.99  1.01  Female     No  Sun  Dinner     2               18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3               12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3               24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2               26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4               28.20

# %%
df2.sort_values("total_bill_tip_sum",ascending= False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  total_bill_tip_sum
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3               60.81
# 212       48.33   9.00    Male     No   Sat  Dinner     4               57.33
# 59        48.27   6.73    Male     No   Sat  Dinner     4               55.00
# 156       48.17   5.00    Male     No   Sun  Dinner     6               53.17
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3               48.85
# ..          ...    ...     ...    ...   ...     ...   ...                 ...
# 218        7.74   1.44    Male    Yes   Sat  Dinner     2                9.18
# 195        7.56   1.44    Male     No  Thur   Lunch     2                9.00
# 111        7.25   1.00  Female     No   Sat  Dinner     1                8.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2                6.75
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1                4.07
#
# [244 rows x 8 columns]

# %%
df2_total = df2.sort_values("total_bill_tip_sum",ascending= False).head(30)

# %%
df2_total.head()
# Out:
#      total_bill    tip   sex smoker  day    time  size  total_bill_tip_sum
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3               60.81
# 212       48.33   9.00  Male     No  Sat  Dinner     4               57.33
# 59        48.27   6.73  Male     No  Sat  Dinner     4               55.00
# 156       48.17   5.00  Male     No  Sun  Dinner     6               53.17
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3               48.85
