# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# categorical : bar graph or countplot
# numerical : hist boxplot

# %%
df = sns.load_dataset("titanic")

# %%
df["sex"].value_counts().plot(kind = "bar")
plt.show()

# %%
plt.hist(df["age"])
plt.show()

# %%
plt.boxplot(df["fare"])
plt.show()

# %%
df = sns.load_dataset("tips")

# %%
sns.countplot(x = df["sex"],data = df)
# Out:
# /Users/fatihozkan/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x = df["total_bill"])
plt.show()
